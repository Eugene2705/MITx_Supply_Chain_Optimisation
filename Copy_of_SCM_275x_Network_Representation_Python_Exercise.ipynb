# %% [markdown]
# <a href="https://colab.research.google.com/github/Eugene2705/MITx_Supply_Chain_Optimisation/blob/main/Copy_of_SCM_275x_Network_Representation_Python_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# SCM.275x - Advanced Supply Chain Systems Planning and Network Design
# # **Network Representation - Python Exercise**

# %% [markdown]
# ### *Before starting, make sure to save a copy of this notebook to your Google Drive!*

# %% [markdown]
# ## **Initialization**

# %%
# !pip install folium     
# !pip install geopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\yevhe\appdata\roaming\python\python313\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from folium) (2.3.1)
# Requirement already satisfied: requests in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from folium) (2025.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from requests->folium) (2025.10.5)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: geopy in c:\users\yevhe\appdata\roaming\python\python313\site-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\yevhe\appdata\roaming\python\python313\site-packages (from geopy) (2.1)

# %%
# Import all required packages

import pandas as pd                   # For data manipulation and analysis
import folium                         # For creating interactive maps
import folium.plugins as plugins      # Additional plugins for folium
from geopy.distance import geodesic   # For calculating geodesic distances between two points

# %% [markdown]
# ## **Helper functions**

# %% [markdown]
# ### **Plotting nodes on a map**

# %%
# Defining a function to plot nodes on a map using folium

def plot_nodes(map,                         # Folium map object to plot the nodes on
               nodes,                       # Dictionary of node objects where each node contains attributes like latitude and longitude
               icon,                        # Icon symbol to use for the markers on the map
               color,                       # Color of the marker icon
               background_color,            # Background color of the marker icon
               ):

    # Loop through each node in the dictionary
    for node in nodes.values():

        # Create a folium marker
        marker = folium.Marker(
            location=[node.lat, node.lon],              # Set the marker's location
            popup = (node.ID + "-" + node.name),        # Create a marker popup with the node ID and name
            icon=plugins.BeautifyIcon(                  # Create a marker's icon
                icon=icon,
                icon_shape="circle",
                text_color=color,                       # Set the marker's color
                border_color=color,
                background_color=background_color,
            )
        )

        # Add a folium marker to the map
        marker.add_to(map)

# %% [markdown]
# ### **Computing geodesic distance**

# %%
# Defining a function for computing geodesic distances between two locations

def compute_geodesic_distance(origin,       # Origin node object
                              destination,  # Destination node
                              unit='km'):   # Unit ('km' or 'mi'), default value = 'km'

    # Extract coordinates (latitude and longitude) from origin and destination
    origin_coordinates = [origin.lat, origin.lon]
    destination_coordinates = [destination.lat, destination.lon]

    # Compute distance based on the specified unit ('km' or 'mi')
    if unit == 'km':
        distance = geodesic(origin_coordinates, destination_coordinates).km  # Compute distance in kilometers
    elif unit == 'mi':
        distance = geodesic(origin_coordinates, destination_coordinates).mi  # Compute distance in miles

    return distance  # Return the calculated distance

# %% [markdown]
# ## **Data setup and preprocessing**

# %% [markdown]
# ### **Nodes**

# %% [markdown]
# #### Reading input files

# %%
# File containing customer data
customer_data_file = 'https://raw.githubusercontent.com/scm275/problem_sets_scm275/main/network_representation_exercise/customers.csv'

# Loading customer data into a pandas DataFrame
customers_df = pd.read_csv(customer_data_file)

# Displaying the first few rows of the DataFrame to verify the data
customers_df.head()
# Out:
#     ID        name        lat        lon  demand  selling_price
# 0  C01     Concord  43.206898 -71.537994    9000             13
# 1  C02     Trenton  40.220596 -74.769913   10000             12
# 2  C03      Austin  30.274670 -97.740349   10000             10
# 3  C04  Providence  41.830914 -71.414963    9000             13
# 4  C05  Montpelier  44.262436 -72.580536    7000             15

# %%
# File containing supplier data
supplier_data_file = 'https://raw.githubusercontent.com/scm275/problem_sets_scm275/main/network_representation/suppliers.csv'

# Loading supplier data into a pandas DataFrame
suppliers_df = pd.read_csv(supplier_data_file)

# Displaying the first few rows of the DataFrame to verify the data
suppliers_df.head()
# Out:
#     ID            name        lat         lon  supply
# 0  S01        Columbia  34.000343  -81.033211   40000
# 1  S02  Jefferson City  38.579201  -92.172935   30000
# 2  S03        Santa Fe  35.682240 -105.939728   20000
# 3  S04        Richmond  37.538857  -77.433640   32000
# 4  S05     Carson City  39.163914 -119.766121   20000

# %% [markdown]
# #### Definition of Classes

# %% [markdown]
# ***❗Task 1a: modify the following code to account for a new attribute of customers, `selling_price`***

# %%
# Class representing a Customer object

class Customer():
    def __init__(self, ID, name, lat, lon, demand, selling_price):
        self.ID = ID              # Customer's ID
        self.name = name          # Customer's name
        self.lat = lat            # Customer's latitude
        self.lon = lon            # Customer's longitude
        self.demand = demand
        self.selling_price = selling_price      # Customer's demand

# %%
# Class representing a Supplier object

class Supplier():
    def __init__(self, ID, name, lat, lon, supply):
        self.ID = ID            # Supplier's ID
        self.name = name        # Supplier's name
        self.lat = lat          # Supplier's latitude
        self.lon = lon          # Supplier's longitude
        self.supply = supply    # Supplier's available supply

# %% [markdown]
# #### Creating node objects

# %%
# Initializing an empty dictionary to store node objects
nodes = dict()

# %% [markdown]
# ***❗Task 1b: modify the following code to account for a new attribute of customers, `selling_price`***

# %%
# Creating a dictionary of customer objects
customers = dict()
for i, row in customers_df.iterrows():
    customers[row['ID']] = Customer(ID=row['ID'],           # Customer's ID
                                    name=row['name'],       # Customer's name
                                    lat=row['lat'],         # Customer's latitude
                                    lon=row['lon'],         # Customer's longitude
                                    demand=row['demand'],
                                    selling_price = row['selling_price'])   # Customer's demand

# Merging the customers dictionary into the existing nodes dictionary
nodes = {**nodes, **customers}

# %%
# Creating a dictionary of supplier objects
suppliers = dict()
for i, row in suppliers_df.iterrows():
    suppliers[row['ID']] = Supplier(ID=row['ID'],           # Supplier's ID
                                    name=row['name'],       # Supplier's name
                                    lat=row['lat'],         # Supplier's latitude
                                    lon=row['lon'],         # Supplier's longitude
                                    supply=row['supply'])   # Supplier's available supply

# Merging the suppliers dictionary into the existing nodes dictionary
nodes = {**nodes, **suppliers}

# %%
# Verifying that the total supply is <= total demand

print('Total Supply:', sum([x.supply for x in suppliers.values()]))   # Calculate and print total supply
print('Total Demand:', sum([x.demand for x in customers.values()]))   # Calculate and print total demand
# Out:
# Total Supply: 171000
# Total Demand: 171000

# %% [markdown]
# #### Visualizing node objects

# %%
# Create a new map centered on the US with a zoom level of 5
map = folium.Map([40, -95.0], zoom_start=5)

# Plot customer locations with a warehouse icon, green color, and yellow background
plot_nodes(map=map, nodes=customers, icon='warehouse', color='green', background_color='yellow')

# Plot supplier locations with an industry icon, orange color, and yellow background
plot_nodes(map=map, nodes=suppliers, icon='industry', color='orange', background_color='yellow')

# Add a tile layer for better map visualization (cartodbpositron theme)
folium.TileLayer('cartodbpositron').add_to(map)

# Display the map with all the plotted data
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8a16267c1f93cf98be0de8c2a05d284 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/marslan390/BeautifyMarker/leaflet-beautify-marker-icon.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8a16267c1f93cf98be0de8c2a05d284&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8a16267c1f93cf98be0de8c2a05d284 = L.map(
#                 &quot;map_c8a16267c1f93cf98be0de8c2a05d284&quot;,
#                 {
#                     center: [40.0, -95.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cef936cbc4d8a28dee999b7896dbbb6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cef936cbc4d8a28dee999b7896dbbb6.addTo(map_c8a16267c1f93cf98be0de8c2a05d284);
#
#
#             var marker_ba1a9c7fcf3a2f7ef6167784820c185e = L.marker(
#                 [43.206898, -71.537994],
#                 {
# }
#             ).addTo(map_c8a16267c1f93cf98be0de8c2a05d284);
#
#
#             var beautify_icon_d2f982c963146079b3df6e8599e491a6 = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;warehouse&quot;,
#   &quot;iconShape&quot;: &quot;circle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;green&quot;,
#   &quot;textColor&quot;: &quot;green&quot;,
#   &quot;backgroundColor&quot;: &quot;yellow&quot;,
#   &quot;innerIconStyle&quot;: &quot;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_ba1a9c7fcf3a2f7ef6167784820c185e.setIcon(beautify_icon_d2f982c963146079b3df6e8599e491a6);
#
#
#         var popup_89d24d093cef03a6b51b3b9576dc9fb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29f1f810c7f99f3db92001c760b1df10 = $(`&lt;div id=&quot;html_29f1f810c7f99f3db92001c760b1df10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;C01-Concord&lt;/div&gt;`)[0];
#                 popup_89d24d093cef03a6b51b3b9576dc9fb0.setContent(html_29f1f810c7f99f3db92001c760b1df10);
#
#
#
#         marker_ba1a9c7fcf3a2f7ef6167784820c185e.bindPopup(popup_89d24d093cef03a6b51b3b9576dc9fb0)
#         ;
#
#
#
#
#                 marker_ba1a9c7fcf3a2f7ef6167784820c185e.setIcon(beautify_icon_d2f982c963146079b3df6e8599e491a6);
#
#
#             var marker_d40b2fc735381b0c0051023973088c0e = L.marker(
#                 [40.220596, -74.769913],
#                 {
# }
#             ).addTo(map_c8a16267c1f93cf98be0de8c2a05d284);
#
#
#             var beautify_icon_ef652b2f537004b5604ed3ee9542fb9c = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;warehouse&quot;,
#   &quot;iconShape&quot;: &quot;circle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;green&quot;,
#   &quot;textColor&quot;: &quot;green&quot;,
#   &quot;backgroundColor&quot;: &quot;yellow&quot;,
#   &quot;innerIconStyle&quot;: &quot;&quot;,
#   &quot;spin&quot;: false,
#   &quot;isAlphaNumericIcon&quot;: false,
# }
#             )
#             marker_d40b2fc735381b0c0051023973088c0e.setIcon(beautify_icon_ef652b2f537004b5604ed3ee9542fb9c);
#
#
#         var popup_fa7bafb9b1b52e024b261ef4cb8aaf7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14172d48146d4ecbbbb7bf33380c730d = $(`&lt;div id=&quot;html_14172d48146d4ecbbbb7bf33380c730d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;C02-Trenton&lt;/div&gt;`)[0];
#                 popup_fa7bafb9b1b52e024b261ef4cb8aaf7e.setContent(html_14172d48146d4ecbbbb7bf33380c730d);
#
#
#
#         marker_d40b2fc735381b0c0051023973088c0e.bindPopup(popup_fa7bafb9b1b52e024b261ef4cb8aaf7e)
#         ;
#
#
#
#
#                 marker_d40b2fc735381b0c0051023973088c0e.setIcon(beautify_icon_ef652b2f537004b5604ed3ee9542fb9c);
#
#
#             var marker_07e2be317f8ad2b91f975f3de6459cba = L.marker(
#                 [30.27467, -97.740349],
#                 {
# }
#             ).addTo(map_c8a16267c1f93cf98be0de8c2a05d284);
#
#
#             var beautify_icon_0b4057f8b1246ad474aa6c50a9322478 = new L.BeautifyIcon.icon(
#                 {
#   &quot;icon&quot;: &quot;warehouse&quot;,
#   &quot;iconShape&quot;: &quot;circle&quot;,
#   &quot;borderWidth&quot;: 3,
#   &quot;borderColor&quot;: &quot;green&quot;,
#   &quot;textColor&quot;: &quot

# %% [markdown]
# ### **Arcs**

# %% [markdown]
# #### Arc distances

# %% [markdown]
# ***❗Task 2a: compute distances between suppliers and add them into the `distances` dictionary***
#
# The following code snippet computes the distances between customers and suppliers, storing them in a dictionary called `distances`. Your task is to compute the distances between pairs of suppliers and add those values to the same `distances` dictionary.
#
# *Hint: first loop through all suppliers using s1, supplier1. Then, inside that loop, go through all suppliers again using s2, supplier2.*

# %%
# Creating a dictionary containing distances between customers and suppliers
distances = dict()
for s, supplier in suppliers.items():                                                                   # Iterate over suppliers
    for c, customer in customers.items():                                                               # Iterate over customers
        distances[s, c] = compute_geodesic_distance(origin=customer, destination=supplier, unit='km')   # Calculate and store distance in kilometers

for s1, supplier1 in suppliers.items():
    for s2, supplier2 in suppliers.items():
        distances[s1, s2] = compute_geodesic_distance(origin= supplier1, destination= supplier2, unit = 'km')

# %% [markdown]
# ***❗Task 2b: find a distance between supplier S01 and S04***

# %%
distances['S01', 'S04']
# Out:
# 509.8957707822129

# %% [markdown]
# #### Arc costs

# %%
cost_unit_km = 1.2  # Cost per unit per kilometer

# Creating a dictionary containing unit costs between customers and suppliers
unit_cost = dict()
for s, supplier in suppliers.items():                                                           # Iterate over suppliers
    for c, customer in customers.items():                                                       # Iterate over customers
        unit_cost[s, c] = distances[s, c] * cost_unit_km                                        # Calculate unit cost as distance multiplied by cost per km

# %% [markdown]
# ## **Analyzing the obtained network data**

# %%
# Dictionary of all customers

customers
# Out:
# {'C01': <__main__.Customer at 0x22d75e62ad0>,
#  'C02': <__main__.Customer at 0x22d75d7cb00>,
#  'C03': <__main__.Customer at 0x22d555094d0>,
#  'C04': <__main__.Customer at 0x22d75d37050>,
#  'C05': <__main__.Customer at 0x22d75d35550>,
#  'C06': <__main__.Customer at 0x22d75d375d0>,
#  'C07': <__main__.Customer at 0x22d75d34ad0>,
#  'C08': <__main__.Customer at 0x22d75e75ad0>,
#  'C09': <__main__.Customer at 0x22d75e75cd0>,
#  'C10': <__main__.Customer at 0x22d75e75850>,
#  'C11': <__main__.Customer at 0x22d75e75bd0>,
#  'C12': <__main__.Customer at 0x22d75e5e6d0>,
#  'C13': <__main__.Customer at 0x22d75e5dd50>,
#  'C14': <__main__.Customer at 0x22d75e5cf50>,
#  'C15': <__main__.Customer at 0x22d75e5e0d0>,
#  'C16': <__main__.Customer at 0x22d75e5e950>,
#  'C17': <__main__.Customer at 0x22d75e5e750>,
#  'C18': <__main__.Customer at 0x22d75e5d1d0>,
#  'C19': <__main__.Customer at 0x22d75e5e550>,
#  'C20': <__main__.Customer at 0x22d75e5d750>}

# %%
# Accessing a specific customer object

customers['C01']

# %%
# Accessing the demand information of a customer object

customers['C01'].demand
# Out:
# 9000

# %%
# Dictionary of all distances

distances
# Out:
# {('S01', 'C01'): 1312.8938802396121,
#  ('S01', 'C02'): 886.2955026402644,
#  ('S01', 'C03'): 1627.4628290579406,
#  ('S01', 'C04'): 1211.1823805042338,
#  ('S01', 'C05'): 1351.8400638458058,
#  ('S01', 'C06'): 1001.3821449065863,
#  ('S01', 'C07'): 1388.790944265285,
#  ('S01', 'C08'): 755.3070381113523,
#  ('S01', 'C09'): 1038.0459520408672,
#  ('S01', 'C10'): 1515.4187990236096,
#  ('S01', 'C11'): 873.681466562938,
#  ('S01', 'C12'): 2868.6035920809136,
#  ('S01', 'C13'): 2237.002951450826,
#  ('S01', 'C14'): 1424.0313994511068,
#  ('S01', 'C15'): 786.3504987176916,
#  ('S01', 'C16'): 576.7382275556878,
#  ('S01', 'C17'): 684.2448665722768,
#  ('S01', 'C18'): 786.6692041589341,
#  ('S01', 'C19'): 2220.8141781170266,
#  ('S01', 'C20'): 2188.1198796783424,
#  ('S02', 'C01'): 1807.9104374273222,
#  ('S02', 'C02'): 1507.6037327646927,
#  ('S02', 'C03'): 1053.273188734065,
#  ('S02', 'C04'): 1799.0891417592104,
#  ('S02', 'C05'): 1749.9174415408538,
#  ('S02', 'C06'): 256.1950777779769,
#  ('S02', 'C07'): 355.9812160577384,
#  ('S02', 'C08'): 1444.6745762136131,
#  ('S02', 'C09'): 425.43428687262644,
#  ('S02', 'C10'): 584.868347775894,
#  ('S02', 'C11'): 719.2677754167876,
#  ('S02', 'C12'): 1879.699805231668,
#  ('S02', 'C13'): 1117.79864675267,
#  ('S02', 'C14'): 308.8211092463388,
#  ('S02', 'C15'): 535.777282312805,
#  ('S02', 'C16'): 547.1839603354682,
#  ('S02', 'C17'): 806.010927567125,
#  ('S02', 'C18'): 1328.0799138860248,
#  ('S02', 'C19'): 1113.8499720768643,
#  ('S02', 'C20'): 1154.3228203749334,
#  ('S03', 'C01'): 3053.0504867229006,
#  ('S03', 'C02'): 2770.666400578181,
#  ('S03', 'C03'): 972.5326896967634,
#  ('S03', 'C04'): 3055.75874834233,
#  ('S03', 'C05'): 2980.8780223294993,
#  ('S03', 'C06'): 1503.7538940648722,
#  ('S03', 'C07'): 1256.6380964174482,
#  ('S03', 'C08'): 2707.3699947955665,
#  ('S03', 'C09'): 1246.2068517138537,
#  ('S03', 'C10'): 764.6554448635899,
#  ('S03', 'C11'): 1501.4580345573734,
#  ('S03', 'C12'): 616.84246875137,
#  ('S03', 'C13'): 613.6863691030775,
#  ('S03', 'C14'): 982.0490059202893,
#  ('S03', 'C15'): 1797.391827214285,
#  ('S03', 'C16'): 1726.814278284496,
#  ('S03', 'C17'): 2068.6173514535217,
#  ('S03', 'C18'): 2590.9546225566305,
#  ('S03', 'C19'): 458.0846099110941,
#  ('S03', 'C20'): 1309.6012803826761,
#  ('S04', 'C01'): 803.7994362831428,
#  ('S04', 'C02'): 376.8595169378674,
#  ('S04', 'C03'): 2038.0574198804884,
#  ('S04', 'C04'): 702.2732757815277,
#  ('S04', 'C05'): 850.9220013086107,
#  ('S04', 'C06'): 1091.8206000469747,
#  ('S04', 'C07'): 1457.9380947944044,
#  ('S04', 'C08'): 245.4796657520037,
#  ('S04', 'C09'): 1370.8150779065502,
#  ('S04', 'C10'): 1808.492701131442,
#  ('S04', 'C11'): 1300.0415178557812,
#  ('S04', 'C12'): 3159.7517024696135,
#  ('S04', 'C13'): 2384.4573027445763,
#  ('S04', 'C14'): 1602.0821173990505,
#  ('S04', 'C15'): 798.72791311351,
#  ('S04', 'C16'): 847.3451622239644,
#  ('S04', 'C17'): 553.3636761884195,
#  ('S04', 'C18'): 306.3070080233684,
#  ('S04', 'C19'): 2401.633332541054,
#  ('S04', 'C20'): 2175.479773724016,
#  ('S05', 'C01'): 4014.9415990050666,
#  ('S05', 'C02'): 3819.3831876097656,
#  ('S05', 'C03'): 2237.5250986435385,
#  ('S05', 'C04'): 4055.1417740377155,
#  ('S05', 'C05'): 3912.7719658209085,
#  ('S05', 'C06'): 2579.3484148927882,
#  ('S05', 'C07'): 2229.3877265356386,
#  ('S05', 'C08'): 3785.0508132241457,
#  ('S05', 'C09'): 2485.7949118271627,
#  ('S05', 'C10'): 2009.320578869773,
#  ('S05', 'C11'): 2768.5954580271505,
#  ('S05', 'C12'): 935.6470545917233,
#  ('S05', 'C13'): 1290.5403813161015,
#  ('S05', 'C14'): 2077.4259876184424,
#  ('S05', 'C15'): 2875.4253724305104,
#  ('S05', 'C16'): 2912.8542198835107,
#  ('S05', 'C17'): 3138.2962457766116,
#  ('S05', 'C18'): 3642.8746956749296,
#  ('S05', 'C19'): 1272.4271975603535,
#  ('S05', 'C20'): 1759.8159541596397,
#  ('S06', 'C01'): 191.37718191788545,
#  ('S06', 'C02'): 283.05749227523376,
#  ('S06', 'C03'): 2536.9074055689807,
#  ('S06', 'C04'): 213.83337879673655,
#  ('S06', 'C05'): 202.62435041348863,
#  ('S06', 'C06'): 1367.854843654272,
#  ('S06', 'C07'): 1641.5486523301827,
#  ('S06', 'C08'): 415.5744037313276,
#  ('S06', 'C09'): 1829.755006506523,
#  ('S06', 'C10'): 2194.0551196380297,
#  ('S06', 'C11'): 1846.2031421663876,
#  ('S06', 'C12'): 3483.4238754969288,
#  ('S06', 'C13'): 2568.6610164357235,
#  ('S06', 'C14'): 1885.5393987653333,
#  ('S06', 'C15'): 1087.3492184592628,
#  ('S06', 'C16'): 1330.8239003361334,
#  ('S06', 'C17'): 829.0504645811266,
#  ('S06', 'C18'): 372.1933791565997,
#  ('S06', 'C19'): 2624.295073194559,
#  ('S06', 'C20'): 2178.6071493305312,
#  ('S01', 'S01'): 0.0,
#  ('S01', 'S02'): 1121.1934658281596,
#  ('S01', 'S03'): 2279.5736213866417,
#  ('S01', 'S04'): 509.8957707822129,
#  ('S01', 'S05'): 3486.6081568797026,
#  ('S01', 'S06'): 1150.9800997007676,
#  ('S02', 'S01'): 1121.1934658281596,
#  ('S02', 'S02'): 0.0,
#  ('S02', 'S03'): 1263.463225244211,
#  ('S02', 'S04'): 1297.288530618834,
#  ('S02', 'S05'): 2386.232752303738,
#  ('S02', 'S06'): 1618.882911733302,
#  ('S03', 'S01'): 2279.5736213866417,
#  ('S03', 'S02'): 1263.463225244211,
#  ('S03', 'S03'): 0.0,
#  ('S03', 'S04'): 2548.8029977644005,
#  ('S03', 'S05'): 1281.8661257183635,
#  ('S03', 'S06'): 2867.586657969665,
#  ('S04', 'S01'): 509.8957707822129,
#  ('S04', 'S02'): 1297.288530618834,
#  ('S04', 'S03'): 2548.8029977644005,
#  ('S04', 'S04'): 0.0,
#  ('S04', 'S05'): 3670.9945931019206,
#  ('S04', 'S06'): 648.4393105508633,
#  ('S05', 'S01'): 3486.6081568797026,
#  ('S05', 'S02'): 2386.232752303738,
#  ('S05', 'S03'): 1281.8661257183635,
#  ('S05', 'S04'): 3670.9945931019206,
#  ('S05', 'S05'): 0.0,
#  ('S05', 'S06'): 3847.663893056295,
#  ('S06', 'S01'): 1150.9800997007676,
#  ('S06', 'S02'): 1618.882911733302,
#  ('S06', 'S03'): 2867.586657969665,
#  ('S06', 'S04'): 648.4393105508633,
#  ('S06', 'S05'): 3847.663893056295,
#  ('S06', 'S06'): 0.0}

# %%
# Accessing specific distance

distances['S05', 'C01']
# Out:
# 4014.9415990050666
